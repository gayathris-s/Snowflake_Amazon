# %%
import sys
import logging
import pandas as pd

from snowflake.snowpark import Session, DataFrame, CaseExpr
from snowflake.snowpark.functions import col,lit,row_number, rank, split,cast, when, expr,min, max
from snowflake.snowpark.types import StructType, StringType, StructField, StringType,LongType,DecimalType,DateType,TimestampType
from snowflake.snowpark import Window

# %%
# initiate logging at info level
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%I:%M:%S')

# %%
# snowpark session
def get_snowpark_session() -> Session:
    connection_parameters = {
       "ACCOUNT":"account",
        "USER":"user",
        "PASSWORD":"password",
        "ROLE":"SYSADMIN",
        "DATABASE":"SALES_DWH",
        "SCHEMA":"CONSUMPTION",
        "WAREHOUSE":"SNOWPARK_ETL_WH"
    }
    # creating snowflake session object
    return Session.builder.configs(connection_parameters).create()

# %%
# This is a simple dim table having nation and region.
# fields are 'Country','Region'
def create_region_dim(all_sales_df,session)-> None:
    region_dim_df = all_sales_df.groupBy(col("Country"),col("Region")).count()
    region_dim_df.show(2)
    region_dim_df = region_dim_df.with_column("isActive",lit('Y'))
    region_dim_df = region_dim_df.selectExpr("SALES_DWH.CONSUMPTION.REGION_DIM_SEQ.nextval as region_id_pk","Country", "Region", "isActive") 
    #region_dim_df.write.save_as_table('sales_dwh.consumption.region_dim',mode="append")   

    region_dim_df.show(5)
    # part 2 where delta data will be processed 
    
    existing_region_dim_df = session.sql("select Country, Region from SALES_DWH.CONSUMPTION.REGION_DIM")

    region_dim_df = region_dim_df.join(existing_region_dim_df,region_dim_df['Country']==existing_region_dim_df['Country'],join_type='leftanti')
    region_dim_df.show(5)
    intsert_cnt = int(region_dim_df.count())
    if intsert_cnt>0:
        region_dim_df.write.save_as_table("SALES_DWH.CONSUMPTION.REGION_DIM",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
def create_product_dim(all_sales_df,session)-> None:

    product_dim_df = all_sales_df.with_column("Brand",split(col('MOBILE_KEY'),lit('/'))[0])     \
                                .with_column("Model",split(col('MOBILE_KEY'),lit('/'))[1])      \
                                .with_column("Color",split(col('MOBILE_KEY'),lit('/'))[2])      \
                                .with_column("Memory",split(col('MOBILE_KEY'),lit('/'))[3])     \
                                .select(col('mobile_key'),col('Brand'),col('Model'),col('Color'),col('Memory'))
    
    product_dim_df = product_dim_df.select(col('mobile_key'),                    \
                                        cast(col('Brand'), StringType()).as_("Brand"),\
                                        cast(col('Model'), StringType()).as_("Model"),\
                                        cast(col('Color'), StringType()).as_("Color"),\
                                        cast(col('Memory'), StringType()).as_("Memory")\
                                        )
    
    product_dim_df = product_dim_df.groupBy(col('mobile_key'),col("Brand"),col("Model"),col("Color"),col("Memory")).count()
    product_dim_df = product_dim_df.with_column("isActive",lit('Y'))

    #fetch existing product dim records.
    existing_product_dim_df = session.sql("select mobile_key, Brand, Model, Color, Memory from sales_dwh.consumption.product_dim")
    existing_product_dim_df.count()

    product_dim_df = product_dim_df.join(existing_product_dim_df,["mobile_key", "Brand", "Model", "Color", "Memory"],join_type='leftanti')

    product_dim_df.show(5)

    product_dim_df = product_dim_df.selectExpr("sales_dwh.consumption.product_dim_seq.nextval as product_id_pk","mobile_key","Brand", "Model","Color","Memory", "isActive") 

    product_dim_df.show(5)
    intsert_cnt = int(product_dim_df.count())
    if intsert_cnt>0:
        product_dim_df.write.save_as_table("sales_dwh.consumption.product_dim",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
def create_promocode_dim(all_sales_df,session)-> None:


    promo_code_dim_df = all_sales_df.with_column( "promotion_code", expr("case when promotion_code is null then 'NA' else promotion_code end"))
    promo_code_dim_df = promo_code_dim_df.groupBy(col("promotion_code"),col("country"),col("region")).count()
    promo_code_dim_df = promo_code_dim_df.with_column("isActive",lit('Y'))

    #promo_code_dim_df.show(10)

    
    #fetch existing product dim records.
    existing_promo_code_dim_df = session.sql("select promotion_code, country, region from SALES_DWH.CONSUMPTION.PROMO_CODE_DIM")


    promo_code_dim_df = promo_code_dim_df.join(existing_promo_code_dim_df,["promotion_code", "country", "region"],join_type='leftanti')


    promo_code_dim_df = promo_code_dim_df.selectExpr("sales_dwh.consumption.promo_code_dim_seq.nextval as promo_code_id_pk","promotion_code", "country","region","isActive") 


    intsert_cnt = int(promo_code_dim_df.count())
    if intsert_cnt>0:
        promo_code_dim_df.write.save_as_table("sales_dwh.consumption.promo_code_dim",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
def create_customer_dim(all_sales_df, session) -> None:
    customer_dim_df = all_sales_df.groupBy(col("COUNTRY"),col("REGION"),col("CUSTOMER_NAME"),col("CONCTACT_NO"),col("SHIPPING_ADDRESS")).count()
    customer_dim_df = customer_dim_df.with_column("isActive",lit('Y'))
    customer_dim_df = customer_dim_df.selectExpr("customer_name", "conctact_no","shipping_address","country","region" ,"isactive") 
    #region_dim_df.write.save_as_table('sales_dwh.consumption.region_dim',mode="append")   

    customer_dim_df.show(5)
    # part 2 where delta data will be processed 
    
    existing_customer_dim_df = session.sql("select customer_name,conctact_no,shipping_address,country, region from sales_dwh.consumption.customer_dim")

    customer_dim_df = customer_dim_df.join(existing_customer_dim_df,["customer_name","conctact_no","shipping_address","country", "region"],join_type='leftanti')

    customer_dim_df = customer_dim_df.selectExpr("sales_dwh.consumption.customer_dim_seq.nextval as customer_id_pk","customer_name", "conctact_no","shipping_address","country","region", "isActive") 

    customer_dim_df.show(5)

    intsert_cnt = int(customer_dim_df.count())
    if intsert_cnt>0:
        customer_dim_df.write.save_as_table("sales_dwh.consumption.customer_dim",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
def create_payment_dim(all_sales_df, session) -> None:
    payment_dim_df = all_sales_df.groupBy(col("COUNTRY"),col("REGION"),col("payment_method"),col("payment_provider")).count()
    payment_dim_df = payment_dim_df.with_column("isActive",lit('Y'))

    #region_dim_df.write.save_as_table('sales_dwh.consumption.region_dim',mode="append")   

    payment_dim_df.show(5)
    # part 2 where delta data will be processed 
    
    existing_payment_dim_df = session.sql("select payment_method,payment_provider,country, region from sales_dwh.consumption.payment_dim")

    payment_dim_df = payment_dim_df.join(existing_payment_dim_df,["payment_method","payment_provider","country", "region"],join_type='leftanti')

    payment_dim_df = payment_dim_df.selectExpr("sales_dwh.consumption.payment_dim_seq.nextval as payment_id_pk","payment_method", "payment_provider","country","region", "isActive") 


    intsert_cnt = int(payment_dim_df.count())
    if intsert_cnt>0:
        payment_dim_df.write.save_as_table("sales_dwh.consumption.payment_dim",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
import pandas as pd

def create_date_dim(all_sales_df, session) -> None:
    start_date = all_sales_df.select(min("order_dt").alias("min_order_dt")).collect()[0]['MIN_ORDER_DT']
    end_date = all_sales_df.select(max("order_dt").alias("max_order_dt")).collect()[0]['MAX_ORDER_DT']
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')

    date_dim = pd.DataFrame()
    date_dim['order_dt'] = date_range.date
    date_dim['Year'] = date_range.year
    start_day_of_year = pd.to_datetime(start_date).dayofyear
    date_dim['DayCounter'] = date_range.dayofyear - start_day_of_year + 1
    date_dim['Month'] = date_range.month
    date_dim['Quarter'] = date_range.quarter
    date_dim['Day'] = date_range.day
    date_dim['DayOfWeek'] = date_range.dayofweek
    date_dim['DayName'] = date_range.strftime('%A')
    date_dim['DayOfMonth'] = date_range.day

    # Map DayOfWeek to Weekday/Weekend
    date_dim['Weekday'] = date_dim['DayOfWeek'].map({0: 'Weekday', 1: 'Weekday', 2: 'Weekday', 3: 'Weekday', 4: 'Weekday', 5: 'Weekend', 6: 'Weekend'})

    # Convert date_dim DataFrame to a list of dictionaries
    date_dim_list = date_dim.to_dict(orient='records')

    # Pass the list of dictionaries to create_dataframe()
    date_dim_df = session.create_dataframe(date_dim_list)

    existing_date_dim_df = session.sql("select order_dt from SALES_DWH.CONSUMPTION.DATE_DIM") 
    date_dim_df = date_dim_df.join(existing_date_dim_df,existing_date_dim_df['order_dt']==date_dim_df['order_dt'],join_type='leftanti')
    date_dim_df.show(5)

    date_dim_df = date_dim_df.selectExpr(' \
                                   SALES_DWH.CONSUMPTION.DATE_DIM_SEQ.nextval as date_id_pk, \
                                   order_dt as order_dt, \
                                   Year as order_year, \
                                   Month as order_month, \
                                   Quarter as order_quarter, \
                                   Day as order_day, \
                                   DayOfWeek as order_dayofweek, \
                                   DayName as order_dayname, \
                                   DayOfMonth as order_dayofmonth, \
                                   Weekday as order_weekday\
                                   ')

    intsert_cnt = int(date_dim_df.count())
    if intsert_cnt>0:
        date_dim_df.write.save_as_table("SALES_DWH.CONSUMPTION.DATE_DIM",mode="append")
        print("save operation ran...")
    else:
        print("No insert ...Opps...")

# %%
def main():
    #get the session object and get dataframe
    session = get_snowpark_session()

    in_sales_df = session.sql("select * from sales_dwh.curated.in_sales_order")
    us_sales_df = session.sql("select * from sales_dwh.curated.us_sales_order")
    fr_sales_df = session.sql("select * from sales_dwh.curated.fr_sales_order")

    all_sales_df = in_sales_df.union(us_sales_df).union(fr_sales_df)

    create_region_dim(all_sales_df,session)     #region dimension
    create_product_dim(all_sales_df,session)    #product dimension
    create_promocode_dim(all_sales_df,session)  #promot code dimension
    create_customer_dim(all_sales_df,session)   #customer dimension
    create_payment_dim(all_sales_df,session)    #payment dimension
    create_date_dim(all_sales_df,session)       #date dimension


    date_dim_df = session.sql("select date_id_pk, order_dt from sales_dwh.consumption.date_dim")
    customer_dim_df = session.sql("select customer_id_pk, customer_name, country, region from sales_dwh.consumption.CUSTOMER_DIM")
    payment_dim_df = session.sql("select payment_id_pk, payment_method, payment_provider, country, region from sales_dwh.consumption.PAYMENT_DIM")
    product_dim_df = session.sql("select product_id_pk, mobile_key from sales_dwh.consumption.PRODUCT_DIM")
    promo_code_dim_df = session.sql("select promo_code_id_pk,promotion_code,country, region from sales_dwh.consumption.PROMO_CODE_DIM")
    region_dim_df = session.sql("select region_id_pk,country, region from sales_dwh.consumption.REGION_DIM")

    all_sales_df = all_sales_df.with_column( "promotion_code", expr("case when promotion_code is null then 'NA' else promotion_code end"))
    all_sales_df = all_sales_df.join(date_dim_df, ["order_dt"],join_type='inner')
    all_sales_df = all_sales_df.join(customer_dim_df, ["customer_name","region","country"],join_type='inner')
    all_sales_df = all_sales_df.join(payment_dim_df, ["payment_method", "payment_provider", "country", "region"],join_type='inner')
    #all_sales_df = all_sales_df.join(product_dim_df, ["Brand","Model","Color","Memory"],join_type='inner')
    all_sales_df = all_sales_df.join(product_dim_df, ["mobile_key"],join_type='inner')
    all_sales_df = all_sales_df.join(promo_code_dim_df, ["promotion_code","country", "region"],join_type='inner')
    all_sales_df = all_sales_df.join(region_dim_df, ["country", "region"],join_type='inner')
    all_sales_df = all_sales_df.selectExpr("sales_dwh.consumption.sales_fact_seq.nextval as order_id_pk, \
                                           order_id as order_code,                               \
                                           date_id_pk as date_id_fk,          \
                                           region_id_pk as region_id_fk,            \
                                           customer_id_pk as customer_id_fk,        \
                                           payment_id_pk as payment_id_fk,          \
                                           product_id_pk as product_id_fk,          \
                                           promo_code_id_pk as promo_code_id_fk,    \
                                           order_quantity,                          \
                                           local_total_order_amt,                   \
                                           local_tax_amt,                           \
                                           exhchange_rate,                          \
                                           us_total_order_amt,                      \
                                           usd_tax_amt                              \
                                           ")
    all_sales_df.write.save_as_table("sales_dwh.consumption.sales_fact",mode="append")

if __name__ == '__main__':
    main()
# Out:
# 05:15:57 - INFO - Snowflake Connector for Python Version: 3.7.0, Python Version: 3.8.8, Platform: macOS-10.16-x86_64-i386-64bit
# 05:15:57 - INFO - This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# 05:15:58 - INFO - Snowpark Session information:
# "version" : 1.13.0,
# "python.version" : 3.8.8,
# "python.connector.version" : 3.7.0,
# "python.connector.session.id" : 1276855122608322,
# "os.name" : Darwin
#
# 05:15:58 - INFO - query: [select * from sales_dwh.curated.us_sales_order]
# 05:15:58 - INFO - query execution done
# 05:15:58 - INFO - Number of results in first chunk: 0
# 05:15:58 - INFO - query: [select * from sales_dwh.curated.in_sales_order]
# 05:15:58 - INFO - query execution done
# 05:15:58 - INFO - Number of results in first chunk: 0
# 05:15:58 - INFO - query: [select * from sales_dwh.curated.in_sales_order]
# 05:15:58 - INFO - query execution done
# 05:15:58 - INFO - Number of results in first chunk: 0
# 05:15:58 - INFO - query: [select * from sales_dwh.curated.us_sales_order]
# 05:15:58 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 0
# 05:15:59 - INFO - query: [select * from sales_dwh.curated.fr_sales_order]
# 05:15:59 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 0
# 05:15:59 - INFO - query: [select * from sales_dwh.curated.fr_sales_order]
# 05:15:59 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 0
# 05:15:59 - INFO - query: [SELECT "COUNTRY", "REGION", count(1) AS "COUNT" FROM (( SELECT NULL :: BIGINT AS...]
# 05:15:59 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 0
# 05:15:59 - INFO - query: [SELECT  *  FROM ( SELECT "COUNTRY", "REGION", count(1) AS "COUNT" FROM ((select ...]
# 05:15:59 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 2
# ----------------------------------
# |"COUNTRY"  |"REGION"  |"COUNT"  |
# ----------------------------------
# |IN         |APAC      |11198    |
# |NULL       |NULL      |90       |
# ----------------------------------
#
# 05:15:59 - INFO - query: [SELECT SALES_DWH.CONSUMPTION.REGION_DIM_SEQ.nextval as region_id_pk, Country, Re...]
# 05:15:59 - INFO - query execution done
# 05:15:59 - INFO - Number of results in first chunk: 0
# 05:15:59 - INFO - query: [SELECT SALES_DWH.CONSUMPTION.REGION_DIM_SEQ.nextval as region_id_pk, Country, Re...]
# 05:16:01 - INFO - query execution done
# 05:16:01 - INFO - Number of results in first chunk: 4
# ------------------------------------------------------
# |"REGION_ID_PK"  |"COUNTRY"  |"REGION"  |"ISACTIVE"  |
# ------------------------------------------------------
# |1217            |IN         |APAC      |Y           |
# |1218            |NULL       |NULL      |Y           |
# |1219            |US         |NA        |Y           |
# |1220            |FR         |EU        |Y           |
# ------------------------------------------------------
#
# 05:16:01 - INFO - query: [select Country, Region from SALES_DWH.CONSUMPTION.REGION_DIM]
# 05:16:01 - INFO - query execution done
# 05:16:01 - INFO - Number of results in first chunk: 0
# 05:16:01 - INFO - query: [SELECT "REGION_ID_PK" AS "REGION_ID_PK", "COUNTRY" AS "COUNTRY", "REGION" AS "RE...]
# 05:16:01 - INFO - query execution done
# 05:16:01 - INFO - Number of results in first chunk: 0
# 05:16:01 - INFO - query: [SELECT "COUNTRY" AS "r_865x_COUNTRY", "REGION" AS "r_865x_REGION" FROM (select C...]
# 05:16:01 - INFO - query execution done
# 05:16:01 - INFO - Number of results in first chunk: 0
# 05:16:01 - INFO - query: [SELECT  *  FROM ( SELECT 0 :: BIGINT AS "REGION_ID_PK", NULL :: STRING(16777216)...]
# 05:16:01 - INFO - query execution done
# 05:16:01 - INFO - Number of results in first chunk: 0
# 05:16:01 - INFO - query: [SELECT  *  FROM ( SELECT  *  FROM ( SELECT "REGION_ID_PK" AS "REGION_ID_PK", "CO...]
# 05:16:02 - INFO - query execution done
# 05:16:02 - INFO - Number of results in first chunk: 1
# ------------------------------------------------------
# |"REGION_ID_PK"  |"COUNTRY"  |"REGION"  |"ISACTIVE"  |
# ------------------------------------------------------
# |220             |NULL       |NULL      |Y           |
# ------------------------------------------------------
#
# 05:16:02 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT  *  FROM ( SELECT "REGION_ID...]
# 05:16:03 - INFO - query execution done
# 05:16:03 - INFO - Number of results in first chunk: 1
# 05:16:03 - INFO - query: [SELECT  *  FROM ( SELECT 0 :: BIGINT AS "REGION_ID_PK", NULL :: STRING(16777216)...]
# 05:16:03 - INFO - query execution done
# 05:16:03 - INFO - Number of results in first chunk: 0
# 05:16:03 - INFO - query: [show tables like 'REGION_DIM' in schema SALES_DWH.CONSUMPTION]
# 05:16:03 - INFO - query execution done
# 05:16:03 - INFO - Number of results in first chunk: 1
# 05:16:03 - INFO - query: [INSERT  INTO SALES_DWH.CONSUMPTION.REGION_DIM  SELECT  *  FROM ( SELECT "REGION_...]
# 05:16:04 - INFO - query execution done
# save operation ran...
# 05:16:04 - INFO - query: [SELECT "MOBILE_KEY", "BRAND", "MODEL", "COLOR", "MEMORY", count(1) AS "COUNT" FR...]
# 05:16:04 - INFO - query execution done
# 05:16:04 - INFO - Number of results in first chunk: 0
# 05:16:04 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM (select mobile_key, Brand, Model, Col...]
# 05:16:05 - INFO - query execution done
# 05:16:05 - INFO - Number of results in first chunk: 1
# 05:16:05 - INFO - query: [select mobile_key, Brand, Model, Color, Memory from sales_dwh.consumption.produc...]
# 05:16:05 - INFO - query execution done
# 05:16:05 - INFO - Number of results in first chunk: 0
# 05:16:05 - INFO - query: [SELECT "MOBILE_KEY" AS "MOBILE_KEY", "BRAND" AS "BRAND", "MODEL" AS "MODEL", "CO...]
# 05:16:05 - INFO - query execution done
# 05:16:05 - INFO - Number of results in first chunk: 0
# 05:16:05 - INFO - query: [SELECT "MOBILE_KEY" AS "r_2sey_MOBILE_KEY", "BRAND" AS "r_2sey_BRAND", "MODEL" A...]
# 05:16:05 - INFO - query execution done
# 05:16:05 - INFO - Number of results in first chunk: 0
# 05:16:05 - INFO - query: [SELECT  *  FROM ( SELECT NULL :: STRING(16777216) AS "MOBILE_KEY", NULL :: STRIN...]
# 05:16:05 - INFO - query execution done
# 05:16:05 - INFO - Number of results in first chunk: 0
# 05:16:05 - INFO - query: [SELECT  *  FROM ( SELECT  *  FROM ( SELECT "MOBILE_KEY" AS "MOBILE_KEY", "BRAND"...]
# 05:16:07 - INFO - query execution done
# 05:16:07 - INFO - Number of results in first chunk: 1
# --------------------------------------------------------------------------------
# |"MOBILE_KEY"  |"BRAND"  |"MODEL"  |"COLOR"  |"MEMORY"  |"COUNT"  |"ISACTIVE"  |
# --------------------------------------------------------------------------------
# |NULL          |NULL     |NULL     |NULL     |NULL      |90       |Y           |
# --------------------------------------------------------------------------------
#
# 05:16:07 - INFO - query: [SELECT sales_dwh.consumption.product_dim_seq.nextval as product_id_pk, mobile_ke...]
# 05:16:07 - INFO - query execution done
# 05:16:07 - INFO - Number of results in first chunk: 0
# 05:16:07 - INFO - query: [SELECT sales_dwh.consumption.product_dim_seq.nextval as product_id_pk, mobile_ke...]
# 05:16:07 - INFO - query execution done
# 05:16:07 - INFO - Number of results in first chunk: 1
# ----------------------------------------------------------------------------------------
# |"PRODUCT_ID_PK"  |"MOBILE_KEY"  |"BRAND"  |"MODEL"  |"COLOR"  |"MEMORY"  |"ISACTIVE"  |
# ----------------------------------------------------------------------------------------
# |5576             |NULL          |NULL     |NULL     |NULL     |NULL      |Y           |
# ----------------------------------------------------------------------------------------
#
# 05:16:07 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT sales_dwh.consumption.produc...]
# 05:16:08 - INFO - query execution done
# 05:16:08 - INFO - Number of results in first chunk: 1
# 05:16:08 - INFO - query: [show tables like 'product_dim' in schema sales_dwh.consumption]
# 05:16:08 - INFO - query execution done
# 05:16:08 - INFO - Number of results in first chunk: 1
# 05:16:08 - INFO - query: [INSERT  INTO sales_dwh.consumption.product_dim  SELECT sales_dwh.consumption.pro...]
# 05:16:10 - INFO - query execution done
# save operation ran...
# 05:16:10 - INFO - query: [SELECT "PROMOTION_CODE", "COUNTRY", "REGION", count(1) AS "COUNT" FROM ( SELECT ...]
# 05:16:10 - INFO - query execution done
# 05:16:10 - INFO - Number of results in first chunk: 0
# 05:16:10 - INFO - query: [select promotion_code, country, region from SALES_DWH.CONSUMPTION.PROMO_CODE_DIM...]
# 05:16:10 - INFO - query execution done
# 05:16:10 - INFO - Number of results in first chunk: 0
# 05:16:10 - INFO - query: [SELECT "PROMOTION_CODE" AS "PROMOTION_CODE", "COUNTRY" AS "COUNTRY", "REGION" AS...]
# 05:16:10 - INFO - query execution done
# 05:16:10 - INFO - Number of results in first chunk: 0
# 05:16:10 - INFO - query: [SELECT "PROMOTION_CODE" AS "r_fr9q_PROMOTION_CODE", "COUNTRY" AS "r_fr9q_COUNTRY...]
# 05:16:10 - INFO - query execution done
# 05:16:10 - INFO - Number of results in first chunk: 0
# 05:16:10 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT sales_dwh.consumption.promo_...]
# 05:16:11 - INFO - query execution done
# 05:16:11 - INFO - Number of results in first chunk: 1
# 05:16:11 - INFO - query: [SELECT sales_dwh.consumption.promo_code_dim_seq.nextval as promo_code_id_pk, pro...]
# 05:16:11 - INFO - query execution done
# 05:16:11 - INFO - Number of results in first chunk: 0
# 05:16:11 - INFO - query: [show tables like 'promo_code_dim' in schema sales_dwh.consumption]
# 05:16:11 - INFO - query execution done
# 05:16:11 - INFO - Number of results in first chunk: 1
# 05:16:11 - INFO - query: [INSERT  INTO sales_dwh.consumption.promo_code_dim  SELECT sales_dwh.consumption....]
# 05:16:13 - INFO - query execution done
# save operation ran...
# 05:16:13 - INFO - query: [SELECT "COUNTRY", "REGION", "CUSTOMER_NAME", "CONCTACT_NO", "SHIPPING_ADDRESS", ...]
# 05:16:13 - INFO - query execution done
# 05:16:13 - INFO - Number of results in first chunk: 0
# 05:16:13 - INFO - query: [SELECT customer_name, conctact_no, shipping_address, country, region, isactive F...]
# 05:16:13 - INFO - query execution done
# 05:16:13 - INFO - Number of results in first chunk: 0
# 05:16:13 - INFO - query: [SELECT customer_name, conctact_no, shipping_address, country, region, isactive F...]
# 05:16:13 - INFO - query execution done
# 05:16:13 - INFO - Number of results in first chunk: 5
# ----------------------------------------------------------------------------------------------------------
# |"CUSTOMER_NAME"  |"CONCTACT_NO"  |"SHIPPING_ADDRESS"                |"COUNTRY"  |"REGION"  |"ISACTIVE"  |
# ----------------------------------------------------------------------------------------------------------
# |Siya Brahmbhatt  |9143663433     |29                                |IN         |APAC      |Y           |
# |                 |               |Varty Ganj                        |           |          |            |
# |                 |               |Sonipat-500177                    |           |          |            |
# |Hazel Char       |9108725925     |34/18, Aggarwal Chowk             |IN         |APAC      |Y           |
# |                 |               |Sangli-Miraj & Kupwad 338558      |           |          |            |
# |Onkar Grover     |9147488495     |62/394, Arora Circle              |IN         |APAC      |Y           |
# |                 |               |Alwar 340243                      |           |          |            |
# |Misha Korpal     |9191006791     |635                               |IN         |APAC      |Y           |
# |                 |               |Gour Chowk                        |           |          |            |
# |                 |               |Rourkela-915455                   |           |          |            |
# |Kanav Sengupta   |9147191719     |78, Johal Street, Khandwa-247585  |IN         |APAC      |Y           |
# ----------------------------------------------------------------------------------------------------------
#
# 05:16:13 - INFO - query: [select customer_name,conctact_no,shipping_address,country, region from sales_dwh...]
# 05:16:14 - INFO - query execution done
# 05:16:14 - INFO - Number of results in first chunk: 0
# 05:16:14 - INFO - query: [SELECT "CUSTOMER_NAME" AS "CUSTOMER_NAME", "CONCTACT_NO" AS "CONCTACT_NO", "SHIP...]
# 05:16:14 - INFO - query execution done
# 05:16:14 - INFO - Number of results in first chunk: 0
# 05:16:14 - INFO - query: [SELECT "CUSTOMER_NAME" AS "r_7jtr_CUSTOMER_NAME", "CONCTACT_NO" AS "r_7jtr_CONCT...]
# 05:16:14 - INFO - query execution done
# 05:16:14 - INFO - Number of results in first chunk: 0
# 05:16:14 - INFO - query: [SELECT sales_dwh.consumption.customer_dim_seq.nextval as customer_id_pk, custome...]
# 05:16:14 - INFO - query execution done
# 05:16:14 - INFO - Number of results in first chunk: 0
# 05:16:14 - INFO - query: [SELECT sales_dwh.consumption.customer_dim_seq.nextval as customer_id_pk, custome...]
# 05:16:14 - INFO - query execution done
# 05:16:14 - INFO - Number of results in first chunk: 1
# ---------------------------------------------------------------------------------------------------------------
# |"CUSTOMER_ID_PK"  |"CUSTOMER_NAME"  |"CONCTACT_NO"  |"SHIPPING_ADDRESS"  |"COUNTRY"  |"REGION"  |"ISACTIVE"  |
# ---------------------------------------------------------------------------------------------------------------
# |86107             |NULL             |NULL           |NULL                |NULL       |NULL      |Y           |
# ---------------------------------------------------------------------------------------------------------------
#
# 05:16:14 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT sales_dwh.consumption.custom...]
# 05:16:15 - INFO - query execution done
# 05:16:15 - INFO - Number of results in first chunk: 1
# 05:16:15 - INFO - query: [show tables like 'customer_dim' in schema sales_dwh.consumption]
# 05:16:15 - INFO - query execution done
# 05:16:15 - INFO - Number of results in first chunk: 1
# 05:16:15 - INFO - query: [INSERT  INTO sales_dwh.consumption.customer_dim  SELECT sales_dwh.consumption.cu...]
# 05:16:17 - INFO - query execution done
# save operation ran...
# 05:16:17 - INFO - query: [SELECT "COUNTRY", "REGION", "PAYMENT_METHOD", "PAYMENT_PROVIDER", count(1) AS "C...]
# 05:16:17 - INFO - query execution done
# 05:16:17 - INFO - Number of results in first chunk: 0
# 05:16:17 - INFO - query: [SELECT "COUNTRY", "REGION", "PAYMENT_METHOD", "PAYMENT_PROVIDER", "COUNT", 'Y' A...]
# 05:16:17 - INFO - query execution done
# 05:16:17 - INFO - Number of results in first chunk: 5
# ---------------------------------------------------------------------------------------
# |"COUNTRY"  |"REGION"  |"PAYMENT_METHOD"  |"PAYMENT_PROVIDER"  |"COUNT"  |"ISACTIVE"  |
# ---------------------------------------------------------------------------------------
# |IN         |APAC      |Debit Card        |RuPay               |468      |Y           |
# |IN         |APAC      |Net Banking       |HDBC                |442      |Y           |
# |IN         |APAC      |Debit Card        |Visa                |388      |Y           |
# |IN         |APAC      |Net Banking       |ICICI               |422      |Y           |
# |IN         |APAC      |Digital Wallets   |Paytm               |448      |Y           |
# ---------------------------------------------------------------------------------------
#
# 05:16:17 - INFO - query: [select payment_method,payment_provider,country, region from sales_dwh.consumptio...]
# 05:16:17 - INFO - query execution done
# 05:16:17 - INFO - Number of results in first chunk: 0
# 05:16:17 - INFO - query: [SELECT "COUNTRY" AS "COUNTRY", "REGION" AS "REGION", "PAYMENT_METHOD" AS "PAYMEN...]
# 05:16:17 - INFO - query execution done
# 05:16:17 - INFO - Number of results in first chunk: 0
# 05:16:17 - INFO - query: [SELECT "PAYMENT_METHOD" AS "r_9upg_PAYMENT_METHOD", "PAYMENT_PROVIDER" AS "r_9up...]
# 05:16:17 - INFO - query execution done
# 05:16:17 - INFO - Number of results in first chunk: 0
# 05:16:17 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT sales_dwh.consumption.paymen...]
# 05:16:18 - INFO - query execution done
# 05:16:18 - INFO - Number of results in first chunk: 1
# 05:16:18 - INFO - query: [SELECT sales_dwh.consumption.payment_dim_seq.nextval as payment_id_pk, payment_m...]
# 05:16:18 - INFO - query execution done
# 05:16:18 - INFO - Number of results in first chunk: 0
# 05:16:18 - INFO - query: [show tables like 'payment_dim' in schema sales_dwh.consumption]
# 05:16:18 - INFO - query execution done
# 05:16:18 - INFO - Number of results in first chunk: 1
# 05:16:18 - INFO - query: [INSERT  INTO sales_dwh.consumption.payment_dim  SELECT sales_dwh.consumption.pay...]
# 05:16:19 - INFO - query execution done
# save operation ran...
# 05:16:19 - INFO - query: [SELECT min("ORDER_DT") AS "MIN_ORDER_DT" FROM ((select * from sales_dwh.curated....]
# 05:16:19 - INFO - query execution done
# 05:16:19 - INFO - Number of results in first chunk: 1
# 05:16:19 - INFO - query: [SELECT max("ORDER_DT") AS "MAX_ORDER_DT" FROM ((select * from sales_dwh.curated....]
# 05:16:19 - INFO - query execution done
# 05:16:19 - INFO - Number of results in first chunk: 1
# 05:16:19 - INFO - query: [SELECT $1 AS "ORDER_DT", $2 AS "YEAR", $3 AS "DAYCOUNTER", $4 AS "MONTH", $5 AS ...]
# 05:16:19 - INFO - query execution done
# 05:16:19 - INFO - Number of results in first chunk: 0
# 05:16:19 - INFO - query: [select order_dt from SALES_DWH.CONSUMPTION.DATE_DIM]
# 05:16:19 - INFO - query execution done
# 05:16:19 - INFO - Number of results in first chunk: 0
# 05:16:19 - INFO - query: [SELECT "ORDER_DT" AS "ORDER_DT", "YEAR" AS "YEAR", "DAYCOUNTER" AS "DAYCOUNTER",...]
# 05:16:20 - INFO - query execution done
# 05:16:20 - INFO - Number of results in first chunk: 0
# 05:16:20 - INFO - query: [SELECT "ORDER_DT" AS "r_3ddd_ORDER_DT" FROM (select order_dt from SALES_DWH.CONS...]
# 05:16:20 - INFO - query execution done
# 05:16:20 - INFO - Number of results in first chunk: 0
# 05:16:20 - INFO - query: [SELECT  *  FROM ( SELECT date('2020-9-16') AS "ORDER_DT", 0 :: BIGINT AS "YEAR",...]
# 05:16:20 - INFO - query execution done
# 05:16:20 - INFO - Number of results in first chunk: 0
# 05:16:20 - INFO - query: [SELECT  *  FROM ( SELECT  *  FROM ( SELECT "ORDER_DT" AS "ORDER_DT", "YEAR" AS "...]
# 05:16:20 - INFO - query execution done
# 05:16:20 - INFO - Number of results in first chunk: 0
# -------------------------------------------------------------------------------------------------------------------------
# |"ORDER_DT"  |"YEAR"  |"DAYCOUNTER"  |"MONTH"  |"QUARTER"  |"DAY"  |"DAYOFWEEK"  |"DAYNAME"  |"DAYOFMONTH"  |"WEEKDAY"  |
# -------------------------------------------------------------------------------------------------------------------------
# |            |        |              |         |           |       |             |           |              |           |
# -------------------------------------------------------------------------------------------------------------------------
#
# 05:16:20 - INFO - query: [SELECT count(1) AS "COUNT(LITERAL())" FROM ( SELECT                             ...]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 1
# No insert ...Opps...
# 05:16:21 - INFO - query: [select date_id_pk, order_dt from sales_dwh.consumption.date_dim]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 0
# 05:16:21 - INFO - query: [SELECT "SALES_ORDER_KEY" AS "SALES_ORDER_KEY", "ORDER_ID" AS "ORDER_ID", "ORDER_...]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 0
# 05:16:21 - INFO - query: [SELECT "DATE_ID_PK" AS "DATE_ID_PK", "ORDER_DT" AS "ORDER_DT" FROM (select date_...]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 0
# 05:16:21 - INFO - query: [SELECT  *  FROM (( SELECT NULL :: BIGINT AS "SALES_ORDER_KEY", NULL :: STRING(16...]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 0
# 05:16:21 - INFO - query: [select customer_id_pk, customer_name, country, region from sales_dwh.consumption...]
# 05:16:21 - INFO - query execution done
# 05:16:21 - INFO - Number of results in first chunk: 0
# 05:16:21 - INFO - query: [SELECT "ORDER_DT" AS "ORDER_DT", "SALES_ORDER_KEY" AS "SALES_ORDER_KEY", "ORDER_...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "CUSTOMER_ID_PK" AS "CUSTOMER_ID_PK", "CUSTOMER_NAME" AS "CUSTOMER_NAME",...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT  *  FROM (( SELECT NULL :: DATE AS "ORDER_DT", NULL :: BIGINT AS "SALES_O...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [select payment_id_pk, payment_method, payment_provider, country, region from sal...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "CUSTOMER_NAME" AS "CUSTOMER_NAME", "REGION" AS "REGION", "COUNTRY" AS "C...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "PAYMENT_ID_PK" AS "PAYMENT_ID_PK", "PAYMENT_METHOD" AS "PAYMENT_METHOD",...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT  *  FROM (( SELECT NULL :: STRING(16777216) AS "CUSTOMER_NAME", NULL :: S...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [select product_id_pk, mobile_key from sales_dwh.consumption.PRODUCT_DIM]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "PAYMENT_METHOD" AS "PAYMENT_METHOD", "PAYMENT_PROVIDER" AS "PAYMENT_PROV...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "PRODUCT_ID_PK" AS "PRODUCT_ID_PK", "MOBILE_KEY" AS "MOBILE_KEY" FROM (se...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT  *  FROM (( SELECT NULL :: STRING(16777216) AS "PAYMENT_METHOD", NULL :: ...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [select promo_code_id_pk,promotion_code,country, region from sales_dwh.consumptio...]
# 05:16:22 - INFO - query execution done
# 05:16:22 - INFO - Number of results in first chunk: 0
# 05:16:22 - INFO - query: [SELECT "MOBILE_KEY" AS "MOBILE_KEY", "PAYMENT_METHOD" AS "PAYMENT_METHOD", "PAYM...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [SELECT "PROMO_CODE_ID_PK" AS "PROMO_CODE_ID_PK", "PROMOTION_CODE" AS "PROMOTION_...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [SELECT  *  FROM (( SELECT NULL :: STRING(16777216) AS "MOBILE_KEY", NULL :: STRI...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [select region_id_pk,country, region from sales_dwh.consumption.REGION_DIM]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [SELECT "PROMOTION_CODE" AS "PROMOTION_CODE", "COUNTRY" AS "COUNTRY", "REGION" AS...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [SELECT "REGION_ID_PK" AS "REGION_ID_PK", "COUNTRY" AS "COUNTRY", "REGION" AS "RE...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [SELECT sales_dwh.consumption.sales_fact_seq.nextval as order_id_pk,             ...]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 0
# 05:16:23 - INFO - query: [show tables like 'sales_fact' in schema sales_dwh.consumption]
# 05:16:23 - INFO - query execution done
# 05:16:23 - INFO - Number of results in first chunk: 1
# 05:16:23 - INFO - query: [INSERT  INTO sales_dwh.consumption.sales_fact  SELECT sales_dwh.consumption.sale...]
# 05:16:26 - INFO - query execution done
